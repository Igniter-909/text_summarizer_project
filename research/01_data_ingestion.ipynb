# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\resume_ready_projects\\text_summarizer_project\\research'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\resume_ready_projects\\text_summarizer_project'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
            self,config_filepath = CONFIG_FILE_PATH,
            params_filepath = PARAMS_FILE_PATH):
        
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_roots])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])
        
        data_ingestion_config = DataIngestionConfig(
            root_dir = config.root_dir,
            source_URL = config.source_URL,
            local_data_file= config.local_data_file,
            unzip_dir=config.unzip_dir
        )

        return data_ingestion_config

# %%
import os
import urllib.request as request
import zipfile
from textSummarizer.logging import logger
from textSummarizer.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self,config:DataIngestionConfig):
        self.config = config

    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename,headers = request.urlretrieve(
                url=self.config.source_URL,
                filename=self.config.local_data_file
            )
            logger.info(f"{filename} downloaded! with following info :\n{headers}")

        else:
            logger.info(f"File already exist of size: {get_size(Path(self.config.local_data_file))}")


    def extract_zip_file(self):
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path,exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file,'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\2068471623.py", line 6, in __init__
#     self.config = read_yaml(config_filepath)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "c:\users\hp\onedrive\desktop\resume_ready_projects\text_summarizer_project\src\textSummarizer\utils\common.py", line 15, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: config\\config.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\2068471623.py", line 6, in __init__
#     self.config = read_yaml(config_filepath)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "c:\users\hp\onedrive\desktop\resume_ready_projects\text_summarizer_project\src\textSummarizer\utils\common.py", line 15, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: config\\config.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\2068471623.py", line 7, in __init__
#     self.params = read_yaml(params_filepath)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "c:\users\hp\onedrive\desktop\resume_ready_projects\text_summarizer_project\src\textSummarizer\utils\common.py", line 15, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: params.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\2068471623.py", line 7, in __init__
#     self.params = read_yaml(params_filepath)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "c:\users\hp\onedrive\desktop\resume_ready_projects\text_summarizer_project\src\textSummarizer\utils\common.py", line 15, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: params.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\2068471623.py", line 9, in __init__
#     create_directories([self.config.artifacts_roots])
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "c:\users\hp\onedrive\desktop\resume_ready_projects\text_summarizer_project\src\textSummarizer\utils\common.py", line 27, in create_directories
#     logger.info(f"directory created: {path}")
# Message: 'directory created: artifacts'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\2068471623.py", line 9, in __init__
#     create_directories([self.config.artifacts_roots])
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "c:\users\hp\onedrive\desktop\resume_ready_projects\text_summarizer_project\src\textSummarizer\utils\common.py", line 27, in create_directories
#     logger.info(f"directory created: {path}")
# Message: 'directory created: artifacts'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 3, in <module>
#     data_ingestion_config = config.get_data_ingestion_config()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\2068471623.py", line 14, in get_data_ingestion_config
#     create_directories([config.root_dir])
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "c:\users\hp\onedrive\desktop\resume_ready_projects\text_summarizer_project\src\textSummarizer\utils\common.py", line 27, in create_directories
#     logger.info(f"directory created: {path}")
# Message: 'directory created: artifacts/data_ingestion'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 3, in <module>
#     data_ingestion_config = config.get_data_ingestion_config()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\2068471623.py", line 14, in get_data_ingestion_config
#     create_directories([config.root_dir])
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "c:\users\hp\onedrive\desktop\resume_ready_projects\text_summarizer_project\src\textSummarizer\utils\common.py", line 27, in create_directories
#     logger.info(f"directory created: {path}")
# Message: 'directory created: artifacts/data_ingestion'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 5, in <module>
#     data_ingestion.download_file()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\951840575.py", line 11, in download_file
#     logger.info(f"{filename} downloaded! with following info :\n{headers}")
# Message: 'artifacts/data_ingestion/data.zip downloaded! with following info :\nConnection: close\nContent-Length: 7903594\nCache-Control: max-age=300\nContent-Security-Policy: default-src \'none\'; style-src \'unsafe-inline\'; sandbox\nContent-Type: application/zip\nETag: "dbc016a060da18070593b83afff580c9b300f0b6ea4147a7988433e04df246ca"\nStrict-Transport-Security: max-age=31536000\nX-Content-Type-Options: nosniff\nX-Frame-Options: deny\nX-XSS-Protection: 1; mode=block\nX-GitHub-Request-Id: E791:2B9E23:21F331:2B6F30:66F8D5A1\nAccept-Ranges: bytes\nDate: Sun, 29 Sep 2024 04:20:50 GMT\nVia: 1.1 varnish\nX-Served-By: cache-del21742-DEL\nX-Cache: MISS\nX-Cache-Hits: 0\nX-Timer: S1727583649.443042,VS0,VE709\nVary: Authorization,Accept-Encoding,Origin\nAccess-Control-Allow-Origin: *\nCross-Origin-Resource-Policy: cross-origin\nX-Fastly-Request-ID: 398306bc74431c98f21950a30da516ed360b5330\nExpires: Sun, 29 Sep 2024 04:25:50 GMT\nSource-Age: 0\n\n'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character ']' (0x5d) at index 51
# Call stack:
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\HP\anaconda3\envs\textsu_3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\1803582706.py", line 5, in <module>
#     data_ingestion.download_file()
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_14060\951840575.py", line 11, in download_file
#     logger.info(f"{filename} downloaded! with following info :\n{headers}")
# Message: 'artifacts/data_ingestion/data.zip downloaded! with following info :\nConnection: close\nContent-Length: 7903594\nCache-Control: max-age=300\nContent-Security-Policy: default-src \'none\'; style-src \'unsafe-inline\'; sandbox\nContent-Type: application/zip\nETag: "dbc016a060da18070593b83afff580c9b300f0b6ea4147a7988433e04df246ca"\nStrict-Transport-Security: max-age=31536000\nX-Content-Type-Options: nosniff\nX-Frame-Options: deny\nX-XSS-Protection: 1; mode=block\nX-GitHub-Request-Id: E791:2B9E23:21F331:2B6F30:66F8D5A1\nAccept-Ranges: bytes\nDate: Sun, 29 Sep 2024 04:20:50 GMT\nVia: 1.1 varnish\nX-Served-By: cache-del21742-DEL\nX-Cache: MISS\nX-Cache-Hits: 0\nX-Timer: S1727583649.443042,VS0,VE709\nVary: Authorization,Accept-Encoding,Origin\nAccess-Control-Allow-Origin: *\nCross-Origin-Resource-Policy: cross-origin\nX-Fastly-Request-ID: 398306bc74431c98f21950a30da516ed360b5330\nExpires: Sun, 29 Sep 2024 04:25:50 GMT\nSource-Age: 0\n\n'
# Arguments: ()
